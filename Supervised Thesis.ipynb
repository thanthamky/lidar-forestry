# %% [markdown]
# # Data analysis demonstration of Thantham's master thesis
#
# This demonstration is to show up how the fused lidar metrics and muiltispectral features looks like within forestry data in order to perform tree species classification

# %%
# !pip install pandas matplotlib scikit-learn geopandas folium mapclassify --quiet

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read pre-saved tree metrics with multispectral features

# %%
data = pd.read_csv('./tree_DBH50_metrics_spctrl.csv')

# %% [markdown]
# Show tubular data table of tree data

# %%
data
# Out:
#         Tag                SpeciesNam   DBH    treeXCoord    treeYCoord  \
# 0     32376     Adinandra integerrima  52.5  754820.29999  1.597838e+06
# 1     21160              Aglaia lawii  51.0  754584.90000  1.597701e+06
# 2     21453              Aglaia lawii  65.6  754589.60000  1.597405e+06
# 3     22233              Aglaia lawii  82.3  754617.80000  1.597479e+06
# 4     40518              Aglaia lawii  54.0  754980.29999  1.597423e+06
# ..      ...                       ...   ...           ...           ...
# 768   45464             Toona ciliata  52.1  755078.29999  1.597863e+06
# 769   46196             Toona ciliata  65.0  755095.00000  1.597545e+06
# 770   29387  Triadica cochinchinensis  51.0  754758.89999  1.597858e+06
# 771  225282     Livistona jenkinsiana  53.0  754615.25000  1.597477e+06
# 772   30486           Ficus pubilimba  99.6  754783.39999  1.597434e+06
#
#      treeID     i_mn_fr   h_max     i_mn_sn      i_mean  ...   i_iq     ndgi  \
# 0       775  109.338321  32.623  241.574713   77.441200  ...   72.0 -0.06162
# 1       498  110.581861  36.462  149.174769   73.848466  ...   83.0 -0.17606
# 2       662  156.379569  33.933  234.489918  108.908314  ...  138.0 -0.08789
# 3       305  163.558385  39.547  236.933900  117.176872  ...  151.0 -0.10811
# 4       487  169.232859  36.785  239.587017  119.818710  ...  157.5 -0.13586
# ..      ...         ...     ...         ...         ...  ...    ...      ...
# 768    1818  133.851341  20.516  187.685306   98.305429  ...  118.0 -0.07549
# 769     708  171.106418  32.880  233.716504  116.341742  ...  165.0 -0.08906
# 770     486  119.051003  36.394  194.002604   80.183818  ...   92.0 -0.04937
# 771     305  163.558385  39.547  236.933900  117.176872  ...  151.0 -0.09823
# 772     268  177.307708  40.866  239.447945  113.094652  ...  170.0 -0.04134
#
#          src       si   b2norm      avi       rr     ndwi     ndvi   b4norm
# 0    2.71088  0.96677  0.23942  0.34266  7.08338  0.31263  0.75258  0.11152
# 1    3.22549  0.97224  0.14996  0.28775  5.77324  0.26748  0.70472  0.13380
# 2    3.00893  0.96346  0.36062  0.33848  6.23364  0.35341  0.72351  0.12388
# 3    3.40997  0.97222  0.18918  0.30883  6.78717  0.28637  0.74317  0.11639
# 4    2.62849  0.96760  0.25950  0.31538  5.97200  0.27964  0.71314  0.12932
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 768  4.21358  0.97121  0.17081  0.33376  7.64407  0.36615  0.76863  0.10522
# 769  3.15863  0.96875  0.24237  0.33558  7.07334  0.32412  0.75227  0.11224
# 770  2.43277  0.96215  0.31517  0.33173  6.03912  0.30293  0.71587  0.12587
# 771  3.60662  0.97223  0.20450  0.30821  6.82462  0.29755  0.74440  0.11566
# 772  3.12637  0.96399  0.25277  0.34513  6.77968  0.35490  0.74292  0.11494
#
# [773 rows x 28 columns]

# %% [markdown]
# ## Simple machine learning model to perform classification
#
# most basic and fastest ML model to be demonstration is Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %% [markdown]
# Since the labels are textual, but it is not problamtic for tree-based model, we are good to go using texual labels as tree specie names

# %%
y = data['SpeciesNam']
X = data.iloc[:, 6:]

# %% [markdown]
# Splitting data of X and y with 30% testing ratio

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# Initialize model

# %%
model = RandomForestClassifier()

# %% [markdown]
# Train the model with training set `X_train` and `y_train`

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# It would be fast to use RF with short time training. Then, predict Tree species using `X_test`

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# Show classification report by comparing `y_test` with `y_pred`

# %%
print(classification_report(y_test, y_pred))
# Out:
#                             precision    recall  f1-score   support
#
#   Acrocarpus fraxinifolius       0.00      0.00      0.00         1
#               Aglaia lawii       0.00      0.00      0.00         2
#          Alphonsea boniana       0.00      0.00      0.00         8
#           Altingia excelsa       0.00      0.00      0.00         1
#    Anthocephalus chinensis       0.00      0.00      0.00         2
#         Antiaris toxicaria       0.00      0.00      0.00         2
#          Aquilaria crassna       0.00      0.00      0.00         2
#           Balakata baccata       0.14      0.12      0.13         8
#     Beilschmiedia maingayi       0.00      0.00      0.00         1
#              Bhesa robusta       0.00      0.00      0.00         1
#     Buchanania arborescens       0.00      0.00      0.00         1
#         Canarium euphyllum       0.00      0.00      0.00         1
#         Carallia brachiata       0.00      0.00      0.00         3
# Castanopsis acuminatissima       0.11      0.09      0.10        11
#   Choerospondias axillaris       0.21      0.61      0.31        23
#        Chukrasia tabularis       0.00      0.00      0.00         2
#      Cinnamomum ilicioides       0.25      0.10      0.14        10
#      Cinnamomum subavenium       0.00      0.00      0.00         5
#     Dipterocarpus gracilis       0.48      0.81      0.60        36
#       Duabanga grandiflora       0.00      0.00      0.00         0
#     Elaeocarpus sphaericus       0.00      0.00      0.00         2
#       Erythrina subumbrans       0.00      0.00      0.00         4
#         Eugenia cerasoides       1.00      0.12      0.22         8
#            Eugenia grandis       0.00      0.00      0.00         0
#        Eugenia syzygioides       0.00      0.00      0.00         2
#            Ficus altissima       0.00      0.00      0.00         1
#             Ficus annulata       0.00      0.00      0.00         1
#           Ficus glaberrima       0.00      0.00      0.00         1
#              Ficus nervosa       0.00      0.00      0.00         4
#            Ficus pubilimba       0.00      0.00      0.00         1
#            Ficus variegata       0.00      0.00      0.00         1
#         Gironniera nervosa       0.00      0.00      0.00         4
#          Helicia formosana       0.00      0.00      0.00         1
#               Hopea ferrea       0.00      0.00      0.00         1
#              Hopea odorata       0.00      0.00      0.00         0
#     Horsfieldia amygdalina       0.00      0.00      0.00         1
#            Ilex chevalieri       0.00      0.00      0.00         5
#          Litsea beusekomii       0.00      0.00      0.00         2
#    Lophopetalum wightianum       0.00      0.00      0.00         1
#       Machilus affsalicina       1.00      1.00      1.00         1
#           Machilus gamblei       0.00      0.00      0.00         0
#         Magnolia baillonii       0.06      0.17      0.09         6
#         Mastixia pentandra       0.00      0.00      0.00         5
#            Miliusa lineata       0.00      0.00      0.00         1
#       Nephelium melliferum       0.00      0.00      0.00         4
#          Ormosia sumatrana       0.00      0.00      0.00         1
#          Phoebe lanceolata       0.00      0.00      0.00         0
#           Platea latifolia       0.00      0.00      0.00         1
#      Podocarpus imbricatus       0.00      0.00      0.00         1
#     Podocarpus neriifolius       0.00      0.00      0.00         2
#       Pouteria stellibacca       0.00      0.00      0.00         0
#            Prunus javanica       0.09      0.11      0.10         9
#    Pterocymbium tinctorium       0.00      0.00      0.00         0
#   Pterospermum cinnamomeum       0.00      0.00      0.00         1
#      Quercus quangtriensis       0.00      0.00      0.00         2
#            Rhus rhetsoides       0.00      0.00      0.00         1
#        Sandoricum koetjape       0.00      0.00      0.00         3
#       Sarcosperma arboreum       0.00      0.00      0.00         2
#     Schefflera heptaphylla       0.00      0.00      0.00         1
#           Schima wallichii       0.00      0.00      0.00         8
#              Sloanea sigun       0.17      0.11      0.13        18
#  Symplocos cochinchinensis       0.00      0.00      0.00         1
#       Tetrameles nudiflora       0.00      0.00      0.00         2
#              Toona ciliata       0.33      0.50      0.40         2
#
#                   accuracy                           0.23       232
#                  macro avg       0.06      0.06      0.05       232
#               weighted avg       0.18      0.23      0.17       232
# /home/user/miniconda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/user/miniconda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/user/miniconda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/user/miniconda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/user/miniconda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/user/miniconda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# Since we seee qustioning result from testing performance, try to report by all dataset

# %%
print(classification_report(y, model.predict(X)))
# Out:
#                              precision    recall  f1-score   support
#
#    Acrocarpus fraxinifolius       0.00      0.00      0.00         1
#       Adinandra integerrima       1.00      1.00      1.00         1
#                Aglaia lawii       1.00      0.60      0.75         5
#        Albizia attopeuensis       1.00      1.00      1.00         1
#           Alphonsea boniana       0.92      0.60      0.73        20
#          Alstonia scholaris       1.00      1.00      1.00         1
#            Altingia excelsa       1.00      0.88      0.93         8
#     Anthocephalus chinensis       1.00      0.60      0.75         5
#          Antiaris toxicaria       0.00      0.00      0.00         2
#        Aphananthe cuspidata       1.00      1.00      1.00         3
#          Apodytes dimidiata       1.00      1.00      1.00         1
#           Aquilaria crassna       0.67      0.67      0.67         6
#            Balakata baccata       0.79      0.76      0.77        29
# Beilschmiedia affintermedia       1.00      1.00      1.00         1
#      Beilschmiedia maingayi       1.00      0.80      0.89         5
#               Bhesa robusta       1.00      0.50      0.67         2
#           Bridelia insulana       1.00      1.00      1.00         2
#      Buchanania arborescens       0.00      0.00      0.00         1
#          Canarium euphyllum       1.00      0.80      0.89         5
#          Carallia brachiata       0.67      0.40      0.50         5
#  Castanopsis acuminatissima       0.62      0.57      0.59        23
#  Chisocheton dysoxylifolius       1.00      1.00      1.00         1
#    Choerospondias axillaris       0.60      0.90      0.72        89
#         Chukrasia tabularis       1.00      0.33      0.50         3
#       Cinnamomum ilicioides       0.83      0.62      0.71        24
#       Cinnamomum subavenium       0.73      0.76      0.74        21
#      Daphniphyllum beddomei       1.00      1.00      1.00         1
#      Dipterocarpus gracilis       0.79      0.94      0.86       127
#        Duabanga grandiflora       0.50      1.00      0.67         1
#       Dysoxylum arborescens       1.00      1.00      1.00         1
#      Elaeocarpus sphaericus       0.75      0.60      0.67         5
#        Erythrina subumbrans       0.67      0.50      0.57         8
#          Eugenia cerasoides       1.00      0.74      0.85        27
#             Eugenia grandis       0.83      1.00      0.91         5
#         Eugenia syzygioides       0.67      0.73      0.70        11
#             Euonymus glaber       1.00      1.00      1.00         2
#             Ficus altissima       0.67      0.67      0.67         3
#              Ficus annulata       1.00      0.67      0.80         3
#              Ficus concinna       1.00      1.00      1.00         1
#            Ficus glaberrima       1.00      0.50      0.67         2
#                Ficus kurzii       1.00      1.00      1.00         4
#               Ficus nervosa       1.00      0.64      0.78        11
#             Ficus pubilimba       0.00      0.00      0.00         1
#               Ficus stricta       1.00      1.00      1.00         4
#             Ficus variegata       0.00      0.00      0.00         1
#         Fraxinus floribunda       1.00      1.00      1.00         3
#          Gironniera nervosa       1.00      0.56      0.71         9
#           Helicia formosana       0.00      0.00      0.00         1
#                Hopea ferrea       0.00      0.00      0.00         1
#               Hopea odorata       0.50      1.00      0.67         1
#      Horsfieldia amygdalina       1.00      0.50      0.67         2
#             Ilex chevalieri       0.88      0.58      0.70        12
#           Litsea beusekomii       0.67      0.50      0.57         4
#       Livistona jenkinsiana       1.00      1.00      1.00         1
#     Lophopetalum wightianum       0.00      0.00      0.00         1
#         Macaranga siamensis       1.00      1.00      1.00         2
#        Machilus affsalicina       1.00      1.00      1.00         2
#            Machilus gamblei       0.83      1.00      0.91         5
#          Magnolia baillonii       0.67      0.86      0.76        36
#   Mangifera cochinchinensis       1.00      1.00      1.00         2
#        Mangifera duperreana       1.00      1.00      1.00         1
#          Mastixia pentandra       0.79      0.69      0.73        16
#            Meliosma pinnata       1.00      1.00      1.00         1
#             Miliusa lineata       1.00      0.67      0.80         3
#        Nephelium melliferum       0.78      0.78      0.78        18
#           Ormosia sumatrana       0.50      0.67      0.57         3
#               Phoebe cathia       1.00      1.00      1.00         2
#           Phoebe lanceolata       0.50      1.00      0.67         1
#            Platea latifolia       0.90      0.90      0.90        10
#       Platymitra macrocarpa       1.00      1.00      1.00         2
#       Podocarpus imbricatus       1.00      0.50      0.67         2
#      Podocarpus neriifolius       0.75      0.75      0.75         8
#        Pouteria stellibacca       0.67      1.00      0.80         2
#              Prunus arborea       1.00      1.00      1.00         2
#             Prunus javanica       0.66      0.70      0.68        27
#     Pterocymbium tinctorium       0.50      1.00      0.67         1
#    Pterospermum cinnamomeum       1.00      0.67      0.80         3
#       Quercus quangtriensis       0.00      0.00      0.00         2
#             Rhus rhetsoides       0.00      0.00      0.00         1
#         Sandoricum koetjape       1.00      0.57      0.73         7
#        Sarcosperma arboreum       1.00      0.60      0.75         5
#      Schefflera heptaphylla       1.00      0.50      0.67         2
#            Schima wallichii       0.89      0.50      0.64        16
#             Shorea henryana       1.00      1.00      1.00         1
#               Sloanea sigun       0.77      0.67      0.72        49
#   Symplocos cochinchinensis       1.00      0.83      0.91         6
#      Tetradium glabrifolium       1.00      1.00      1.00         1
#        Tetrameles nudiflora       0.75      0.60      0.67         5
#               Toona ciliata       0.82      0.90      0.86        10
#    Triadica cochinchinensis       1.00      1.00      1.00         1
#
#                    accuracy                           0.77       773
#                   macro avg       0.78      0.71      0.73       773
#                weighted avg       0.78      0.77      0.76       773
# /home/user/miniconda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/user/miniconda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/user/miniconda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# Training set and Testing set were blended together. result is somehow acceptable. Next, append the predictions to original dataset

# %%
data['pred'] = model.predict(X)

# %% [markdown]
# Since we are handling semi-geospatial data, we can transform it and show on this jupyter using folium map module

# %%
gdf = gpd.GeoDataFrame(
    data, geometry=gpd.points_from_xy(data.treeXCoord, data.treeYCoord), crs="EPSG:32648"
)

# %%
m = gdf.explore(tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
                attr='ESRI Imagery',
                width='100%',
                height='900px')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c1847696ef8f90c9a9ff37c1aeafbac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 900.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c1847696ef8f90c9a9ff37c1aeafbac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c1847696ef8f90c9a9ff37c1aeafbac = L.map(
#                 &quot;map_5c1847696ef8f90c9a9ff37c1aeafbac&quot;,
#                 {
#                     center: [14.439369981581304, 107.36336458500853],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5c1847696ef8f90c9a9ff37c1aeafbac);
#
#
#
#
#
#             var tile_layer_d9e257b5eb212b5eea22daf26aff01e9 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;ESRI Imagery&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d9e257b5eb212b5eea22daf26aff01e9.addTo(map_5c1847696ef8f90c9a9ff37c1aeafbac);
#
#
#             map_5c1847696ef8f90c9a9ff37c1aeafbac.fitBounds(
#                 [[14.437111823690415, 107.36049642696592], [14.441628139472193, 107.36623274305113]],
#                 {}
#             );
#
#
#         function geo_json_45745be9fd9f29c3d1d558e312f3e507_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_45745be9fd9f29c3d1d558e312f3e507_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_45745be9fd9f29c3d1d558e312f3e507_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_45745be9fd9f29c3d1d558e312f3e507_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_45745be9fd9f29c3d1d558e312f3e507_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_45745be9fd9f29c3d1d558e312f3e507.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_45745be9fd9f29c3d1d558e312f3e507_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_45745be9fd9f29c3d1d558e312f3e507 = L.geoJson(null, {
#                 onEachFeature: geo_json_45745be9fd9f29c3d1d558e312f3e507_onEachFeature,
#
#                 style: geo_json_45745be9fd9f29c3d1d558e312f3e507_styler,
#                 pointToLayer: geo_json_45745be9fd9f29c3d1d558e312f3e507_pointToLayer,
#         });
#
#         function geo_json_45745be9fd9f29c3d1d558e312f3e507_add (data) {
#             geo_json_45745be9fd9f29c3d1d558e312f3e507
#                 .addData(data);
#         }
#             geo_json_45745be9fd9f29c3d1d558e312f3e507_add({&quot;bbox&quot;: [107.36049642696592, 14.437111823690415, 107.36623274305113, 14.441628139472193], &quot;features&quot;: [{&quot;bbox&quot;: [107.36363822734658, 14.441248158615617, 107.36363822734658, 14.441248158615617], &quot;geometry&quot;: {&quot;coordinates&quot;: [107.36363822734658, 14.441248158615617], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;DBH&quot;: 52.5, &quot;P50h&quot;: 15.443, &quot;P90h&quot;: 28.9488, &quot;SpeciesNam&quot;: &quot;Adinandra integerrima&quot;, &quot;Tag&quot;: 32376, &quot;avi&quot;: 0.34266, &quot;b2norm&quot;: 0.23942, &quot;b4norm&quot;: 0.11152, &quot;h_75nrm&quot;: 0.747733219740766, &quot;h_max&quot;: 32.623, &quot;h_mean&quot;: 15.632823359537944, &quot;h_mn_sn&quot;: 13.61712183908046, &quot;i_cv&quot;: 105.35433120892948, &quot;i_iq&q
